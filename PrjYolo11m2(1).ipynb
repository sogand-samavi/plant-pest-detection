# %%
# !nvidia-smi
# Out:
# Thu Jul 10 18:57:21 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 23.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 40.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 28.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 40.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 60.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !mkdir -p /content/drive/MyDrive/yolo-pest-project101

# %%
# !yolo task=detect \
  mode=train \
  model=yolo11m.pt \
  data=/content/drive/MyDrive/prj.dataset4/D.yaml \
  epochs=100 \
  imgsz=640 \
  batch=16 \
  project=/content/drive/MyDrive/yolo-pest-project101 \
  name=run
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 38.8M/38.8M [00:00<00:00, 270MB/s]
# Ultralytics 8.3.163 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect \
  mode=val \
  model=/content/drive/MyDrive/yolo-pest-project101/run/weights/best.pt \
  data=/content/drive/MyDrive/prj.dataset4/D.yaml \
  split=test \
  imgsz=640 \
  batch=16 \
  project=/content/drive/MyDrive/yolo-pest-project101/runs_val \
  name=test_results \
  exist_ok=True
# Out:
# Ultralytics 8.3.163 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 125 layers, 20,033,887 parameters, 0 gradients, 67.7 GFLOPs
# val: Fast image access ✅ (ping: 0.4±0.2 ms, read: 0.7±0.6 MB/s, size: 236.9 KB)
# val: Scanning /content/drive/MyDrive/prj.dataset4/labels/test.cache... 97 images, 0 backgrounds, 0 corrupt: 100% 97/97 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:26<00:00,  3.75s/it]
#                    all         97        228      0.853       0.74      0.835       0.58
#  سوسک سیب زمینی کلرادو         17        115      0.848      0.629      0.729      0.431
#          کرم غوزه پنبه         22         23      0.731      0.913      0.926      0.749
#  کرم شاخدار گوجه فرنگی         19         44      0.791      0.602      0.748      0.563
#                    ملخ         20         27       0.95      0.667      0.812        0.5
# ...

# %%
# !yolo task=detect \
  mode=predict \
  model=/content/drive/MyDrive/yolo-pest-project101/run/weights/best.pt \
  source=/content/drive/MyDrive/prj.dataset4/images/test \
  imgsz=640 \
  conf=0.6 \
  save=True \
  project=/content/drive/MyDrive/yolo-pest-project101/runs_predict \
  name=test_results \
  exist_ok=True
# Out:
# Ultralytics 8.3.163 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 125 layers, 20,033,887 parameters, 0 gradients, 67.7 GFLOPs
#
# image 1/97 /content/drive/MyDrive/prj.dataset4/images/test/Horn_10.jpg: 480x640 2 کرم شاخدار گوجه فرنگیs, 76.6ms
# image 2/97 /content/drive/MyDrive/prj.dataset4/images/test/Horn_102.jpeg: 480x640 1 کرم شاخدار گوجه فرنگی, 29.2ms
# image 3/97 /content/drive/MyDrive/prj.dataset4/images/test/Horn_107.jpeg: 480x640 5 کرم شاخدار گوجه فرنگیs, 29.3ms
# image 4/97 /content/drive/MyDrive/prj.dataset4/images/test/Horn_108.jpeg: 640x384 1 کرم شاخدار گوجه فرنگی, 45.6ms
# image 5/97 /content/drive/MyDrive/prj.dataset4/images/test/Horn_110.jpeg: 480x640 3 کرم شاخدار گوجه فرنگیs, 30.1ms
# image 6/97 /content/drive/MyDrive/prj.dataset4/images/test/Horn_12.jpg: 512x640 (no detections), 45.8ms
# image 7/97 /content/drive/MyDrive/prj.dataset4/images/test/Horn_17.jpg: 448x640 (no detections), 45.4ms
# ...

# %%
# !yolo task=detect \
  mode=val \
  model=/content/drive/MyDrive/yolo-pest-project101/run/weights/best.pt \
  data=/content/drive/MyDrive/prj.dataset4/D.yaml \
  split=test
# Out:
# Ultralytics 8.3.163 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 125 layers, 20,033,887 parameters, 0 gradients, 67.7 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.1 ms, read: 113.3±64.8 MB/s, size: 288.0 KB)
# val: Scanning /content/drive/MyDrive/prj.dataset4/labels/test.cache... 97 images, 0 backgrounds, 0 corrupt: 100% 97/97 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:03<00:00,  1.91it/s]
#                    all         97        228      0.853       0.74      0.835       0.58
#  سوسک سیب زمینی کلرادو         17        115      0.848      0.629      0.729      0.431
#          کرم غوزه پنبه         22         23      0.731      0.913      0.926      0.749
#  کرم شاخدار گوجه فرنگی         19         44      0.791      0.602      0.748      0.563
#                    ملخ         20         27       0.95      0.667      0.812        0.5
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/yolo-pest-project101/run/weights/best.pt \ source=/content/drive/MyDrive/prj.dataset4/images/test save_txt=True save_conf=True
# Out:
# Ultralytics 8.3.163 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11m summary (fused): 125 layers, 20,033,887 parameters, 0 gradients, 67.7 GFLOPs
#
# image 1/97 /content/drive/MyDrive/prj.dataset4/images/test/Horn_10.jpg: 480x640 3 کرم شاخدار گوجه فرنگیs, 60.1ms
# image 2/97 /content/drive/MyDrive/prj.dataset4/images/test/Horn_102.jpeg: 480x640 1 کرم شاخدار گوجه فرنگی, 29.3ms
# image 3/97 /content/drive/MyDrive/prj.dataset4/images/test/Horn_107.jpeg: 480x640 5 کرم شاخدار گوجه فرنگیs, 29.2ms
# image 4/97 /content/drive/MyDrive/prj.dataset4/images/test/Horn_108.jpeg: 640x384 1 کرم شاخدار گوجه فرنگی, 44.2ms
# image 5/97 /content/drive/MyDrive/prj.dataset4/images/test/Horn_110.jpeg: 480x640 3 کرم شاخدار گوجه فرنگیs, 29.0ms
# image 6/97 /content/drive/MyDrive/prj.dataset4/images/test/Horn_12.jpg: 512x640 (no detections), 46.3ms
# image 7/97 /content/drive/MyDrive/prj.dataset4/images/test/Horn_17.jpg: 448x640 (no detections), 45.4ms
# ...
